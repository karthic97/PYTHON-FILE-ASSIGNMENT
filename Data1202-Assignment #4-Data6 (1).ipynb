# %%
#Importing Python Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
print("Done")
# Out:
# Done

# %%
#Loading Dataset
df_youtube = pd.read_csv('youtube_dataset.csv', encoding='latin1')
df_youtube.head()
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0   1553043067-5148  https://socialblade.com/youtube/top/5000/mosts...
# 1   1553043063-5147  https://socialblade.com/youtube/top/5000/mosts...
# 2   1553043059-5146  https://socialblade.com/youtube/top/5000/mosts...
# 3   1553043055-5145  https://socialblade.com/youtube/top/5000/mosts...
# 4   1553043051-5144  https://socialblade.com/youtube/top/5000/mosts...
#
#            userID                                        userID-href  \
# 0       PewDiePie        https://socialblade.com/youtube/c/pewdiepie
# 1        T-Series     https://socialblade.com/youtube/c/tseriesmusic
# 2          Gaming  https://socialblade.com/youtube/channel/UCOpNc...
# 3  YouTube Movies  https://socialblade.com/youtube/channel/UClgRk...
# 4          Sports  https://socialblade.com/youtube/channel/UCEgdi...
#
#              name  uploads  subscribers   videoviews country    channeltype  \
# ...

# %%
# Sorting Data Based on Suscribers
df_sorted = df_youtube.sort_values(by=['subscribers'],ascending = False)
df_sorted.head()
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0   1553043067-5148  https://socialblade.com/youtube/top/5000/mosts...
# 1   1553043063-5147  https://socialblade.com/youtube/top/5000/mosts...
# 2   1553043059-5146  https://socialblade.com/youtube/top/5000/mosts...
# 3   1553043055-5145  https://socialblade.com/youtube/top/5000/mosts...
# 4   1553043051-5144  https://socialblade.com/youtube/top/5000/mosts...
#
#            userID                                        userID-href  \
# 0       PewDiePie        https://socialblade.com/youtube/c/pewdiepie
# 1        T-Series     https://socialblade.com/youtube/c/tseriesmusic
# 2          Gaming  https://socialblade.com/youtube/channel/UCOpNc...
# 3  YouTube Movies  https://socialblade.com/youtube/channel/UClgRk...
# 4          Sports  https://socialblade.com/youtube/channel/UCEgdi...
#
#              name  uploads  subscribers   videoviews country    channeltype  \
# ...

# %%
#Subsetting the top 1000 Channels
df_filtered = df_sorted.iloc[:1000]
df_filtered.head()
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0   1553043067-5148  https://socialblade.com/youtube/top/5000/mosts...
# 1   1553043063-5147  https://socialblade.com/youtube/top/5000/mosts...
# 2   1553043059-5146  https://socialblade.com/youtube/top/5000/mosts...
# 3   1553043055-5145  https://socialblade.com/youtube/top/5000/mosts...
# 4   1553043051-5144  https://socialblade.com/youtube/top/5000/mosts...
#
#            userID                                        userID-href  \
# 0       PewDiePie        https://socialblade.com/youtube/c/pewdiepie
# 1        T-Series     https://socialblade.com/youtube/c/tseriesmusic
# 2          Gaming  https://socialblade.com/youtube/channel/UCOpNc...
# 3  YouTube Movies  https://socialblade.com/youtube/channel/UClgRk...
# 4          Sports  https://socialblade.com/youtube/channel/UCEgdi...
#
#              name  uploads  subscribers   videoviews country    channeltype  \
# ...

# %%
# Function to calculating the distirbution of All Channel Type
# Data Distribution
print(df_youtube.groupby('channeltype')['channeltype'].count().reset_index(name='Channel Count').sort_values(['Channel Count'],
     ascending=False))

# Bar Chart
df_youtube['channeltype'].value_counts().plot(kind='bar')
plt.ylabel('Channel Count')
plt.xlabel('Channel Type')
plt.title('Channel Type Distribution - All (Before)')
# Out:
#       channeltype  Channel Count
# 4   Entertainment           1037
# 8           Music            760
# 6           Games            449
# 11         People            392
# 2          Comedy            275
# 7           Howto            223
# 5            Film            176
# 3       Education            142
# 14           Tech             78
# 13         Sports             56
# 9            News             55
# 1           Autos             14
# 15         Travel             11
# 0         Animals              9
# 10      Nonprofit              3
# 12          Shows              1
# Text(0.5, 1.0, 'Channel Type Distribution - All (Before)')

# %%
# Function to calculating the distirbution of Top 1000 Channel Type
# Data Distribution
print(df_filtered.groupby('channeltype')['channeltype'].count().reset_index(name='Channel Count').sort_values(['Channel Count'],
      ascending=False))

# Bar Chart
df_filtered['channeltype'].value_counts().plot(kind='bar')
plt.ylabel('Channel Count')
plt.xlabel('Channel Type')
plt.title('Channel Type Distribution - Top 1000 (After)')
# Out:
#       channeltype  Channel Count
# 4   Entertainment            284
# 8           Music            240
# 6           Games            115
# 2          Comedy             76
# 11         People             72
# 7           Howto             49
# 5            Film             36
# 3       Education             30
# 13           Tech             19
# 9            News             17
# 12         Sports             17
# 1           Autos              3
# 0         Animals              2
# 10      Nonprofit              1
# 14         Travel              1
# Text(0.5, 1.0, 'Channel Type Distribution - Top 1000 (After)')

# %%
#Loading Top 1000 Channels to CSV
df_filtered.to_csv('youtubechannel_top_1000.csv')
